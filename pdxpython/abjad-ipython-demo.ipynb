# %%
# %load_ext abjad.ext.ipython

# %%
from abjad import *

# %%
staff = Staff("c'4 d'4 e'4 f'4")

# %%
show(staff)

# %%
play(staff)
# Out:
# <audio controls type="audio/mpeg" src="data:audio/mpeg;base64,...">
